# %% [markdown]
# | Method         | Description           |
# | -------------- | --------------------- |
# | `read_csv()`   | CSV file read karna   |
# | `read_excel()` | Excel file read karna |
# | `read_json()`  | JSON file read karna  |
# | `read_sql()`   | SQL table read karna  |
# | `to_csv()`     | CSV save karna        |
# | `to_excel()`   | Excel save karna      |
# | `to_json()`    | JSON save karna       |

# %% [markdown]
# | Method       | Description     |
# | ------------ | --------------- |
# | `head()`     | First rows      |
# | `tail()`     | Last rows       |
# | `sample()`   | Random rows     |
# | `info()`     | Dataset summary |
# | `describe()` | Statistics      |
# | `shape`      | Rows, Columns   |
# | `columns`    | Column names    |
# | `index`      | Index values    |
# | `dtypes`     | Data types      |

# %% [markdown]
# row and clumn selection
# | Method   | Description              |
# | -------- | ------------------------ |
# | `loc[]`  | Label based selection    |
# | `iloc[]` | Position based selection |
# | `at[]`   | Single value access      |
# | `iat[]`  | Fast single value access |

# %% [markdown]
# df.loc[0]
# df.iloc[0]
# df.loc[:, ["Name","Age"]]

# %% [markdown]
# missing value
# | Method          | Description             |
# | --------------- | ----------------------- |
# | `isnull()`      | Missing check           |
# | `notnull()`     | Non-missing check       |
# | `fillna()`      | Fill missing            |
# | `dropna()`      | Remove missing          |
# | `interpolate()` | Estimate missing values |

# %% [markdown]
# duplicate handling
# | Method              | Description       |
# | ------------------- | ----------------- |
# | `duplicated()`      | Find duplicates   |
# | `drop_duplicates()` | Remove duplicates |

# %% [markdown]
# | Method           | Description      |
# | ---------------- | ---------------- |
# | `astype()`       | Convert type     |
# | `to_numeric()`   | Convert numeric  |
# | `to_datetime()`  | Convert date     |
# | `to_timedelta()` | Convert duration |

# %% [markdown]
# | Method             | Description    |
# | ------------------ | -------------- |
# | `str.strip()`      | Remove spaces  |
# | `str.lower()`      | Lowercase      |
# | `str.upper()`      | Uppercase      |
# | `str.title()`      | Title Case     |
# | `str.replace()`    | Replace text   |
# | `str.contains()`   | Search pattern |
# | `str.startswith()` | Starts with    |
# | `str.endswith()`   | Ends with      |
# | `str.split()`      | Split text     |
# | `str.extract()`    | Extract regex  |
# | `str.len()`        | Length         |

# %% [markdown]
# df["Name"] = df["Name"].str.strip()

# %% [markdown]
# | Method          | Description |
# | --------------- | ----------- |
# | `sort_values()` | Sort values |
# | `sort_index()`  | Sort index  |

# %% [markdown]
# df[df["Age"] > 18]

# %% [markdown]
# | Method      | Description        |
# | ----------- | ------------------ |
# | `isin()`    | Check list values  |
# | `between()` | Range filter       |
# | `query()`   | SQL-like filtering |

# %% [markdown]
# | Method       | Description              |
# | ------------ | ------------------------ |
# | `replace()`  | Replace values           |
# | `map()`      | Value mapping            |
# | `apply()`    | Custom operation         |
# | `applymap()` | Entire DataFrame         |
# | `where()`    | Keep condition values    |
# | `mask()`     | Replace condition values |
# | `clip()`     | Limit range              |

# %% [markdown]
# | Method     | Description        |
# | ---------- | ------------------ |
# | `sum()`    | Total              |
# | `mean()`   | Average            |
# | `median()` | Middle value       |
# | `mode()`   | Most frequent      |
# | `min()`    | Minimum            |
# | `max()`    | Maximum            |
# | `count()`  | Count              |
# | `std()`    | Standard deviation |
# | `var()`    | Variance           |

# %% [markdown]
# GroupBy (Most Important)
# | Method        | Description           |
# | ------------- | --------------------- |
# | `groupby()`   | Group records         |
# | `agg()`       | Multiple aggregations |
# | `transform()` | Group transformation  |
# | `filter()`    | Filter groups         |

# %% [markdown]
# df.groupby("Department").agg({
#     "Salary":["mean","max","min"]
# })

# %% [markdown]
# ## 13 pivot table

# %% [markdown]
# | Method          | Description      |
# | --------------- | ---------------- |
# | `pivot()`       | Reshape data     |
# | `pivot_table()` | Aggregated pivot |
# | `melt()`        | Unpivot          |
# | `stack()`       | Columns → Rows   |
# | `unstack()`     | Rows → Columns   |

# %% [markdown]
# ## 14 merging join

# %% [markdown]
# | Method     | Description      |
# | ---------- | ---------------- |
# | `merge()`  | SQL join         |
# | `join()`   | Index join       |
# | `concat()` | Combine datasets |

# %% [markdown]
# pd.merge(df1, df2, on="ID")

# %% [markdown]
# ## date and time method

# %% [markdown]
# | Method          | Description        |
# | --------------- | ------------------ |
# | `dt.year`       | Extract year       |
# | `dt.month`      | Extract month      |
# | `dt.day`        | Extract day        |
# | `dt.day_name()` | Weekday            |
# | `dt.quarter`    | Quarter            |
# | `dt.days`       | Difference in days |

# %% [markdown]
# df["Year"] = df["Date"].dt.year

# %% [markdown]
# 16 index operation

# %% [markdown]
# | Method          | Description   |
# | --------------- | ------------- |
# | `set_index()`   | Create index  |
# | `reset_index()` | Reset index   |
# | `reindex()`     | Reorder index |

# %% [markdown]
# df.set_index("ID")

# %% [markdown]
# ## value counting

# %% [markdown]
# | Method           | Description     |
# | ---------------- | --------------- |
# | `value_counts()` | Frequency count |
# | `unique()`       | Unique values   |
# | `nunique()`      | Count unique    |

# %% [markdown]
# df["City"].value_counts()

# %% [markdown]
# ## window function

# %% [markdown]
# | Method        | Description        |
# | ------------- | ------------------ |
# | `rolling()`   | Moving window      |
# | `expanding()` | Cumulative window  |
# | `ewm()`       | Exponential window |

# %% [markdown]
# ## useful utility method

# %% [markdown]
# | Method     | Description         |
# | ---------- | ------------------- |
# | `copy()`   | Copy DataFrame      |
# | `rename()` | Rename columns      |
# | `drop()`   | Remove rows/columns |
# | `insert()` | Insert column       |
# | `assign()` | Add column          |
# | `pipe()`   | Function chaining   |

# %% [markdown]
# df.rename(columns={"Age":"Student_Age"})

# %% [markdown]
# ## 25 most important pandas method

# %% [markdown]
# read_csv()
# head()
# info()
# describe()
# loc[]
# iloc[]
# isnull()
# fillna()
# dropna()
# duplicated()
# drop_duplicates()
# astype()
# replace()
# map()
# apply()
# groupby()
# agg()
# pivot_table()
# merge()
# concat()
# sort_values()
# value_counts()
# query()
# reset_index()
# to_datetime()
